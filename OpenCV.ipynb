# %%
import cv2

# %%
img = cv2.imread("./Downloads/dog.jpg")

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %%
plt.show()

# %%
new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(new_img)
plt.show()
